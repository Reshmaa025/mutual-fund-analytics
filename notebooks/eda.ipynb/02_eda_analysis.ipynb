# %%
import os
os.makedirs("reports/charts", exist_ok=True)

# %% [markdown]
# # Final Insights
#
# - Mutual fund NAVs analyzed successfully
# - SBI, ICICI, Axis, Kotak compared
# - Returns calculated from historical NAV
# - Best performing fund identified
# - Data sourced from mfapi.in API

# %%
best = returns.loc[returns['return_%'].idxmax()]
best
# Out:
# scheme_name    SBI Bluechip
# start_nav          104.7663
# end_nav            103.0059
# return_%          -1.680311
# Name: 4, dtype: object

# %%
plt.figure(figsize=(10,5))
plt.bar(returns['scheme_name'], returns['return_%'])
plt.title("Mutual Fund Returns Comparison")
plt.xticks(rotation=45)
plt.ylabel("Return %")
plt.show()

# %%
returns = df.groupby('scheme_name').agg(
    start_nav=('nav', 'first'),
    end_nav=('nav', 'last')
).reset_index()

returns['return_%'] = ((returns['end_nav'] - returns['start_nav']) / returns['start_nav']) * 100

returns.sort_values('return_%', ascending=False)
# Out:
#         scheme_name  start_nav   end_nav   return_%
# 4      SBI Bluechip   104.7663  103.0059  -1.680311
# 3  Nippon Large Cap    97.4783   14.6967 -84.923106
# 1    ICICI Bluechip   103.5959   15.0253 -85.496241
# 2    Kotak Bluechip   246.8566   30.6076 -87.601061
# 0     Axis Bluechip  6158.9665   23.9920 -99.610454

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(data=df, x="date", y="nav", hue="scheme_name")
plt.title("Mutual Fund Comparison")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df['date'], df['nav'])
plt.title("Mutual Fund NAV Trend")
plt.xlabel("Date")
plt.ylabel("NAV")
plt.show()

# %%
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16712 entries, 0 to 16711
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         16712 non-null  str
#  1   nav          16712 non-null  float64
#  2   scheme_name  16712 non-null  str
#  3   scheme_code  16712 non-null  int64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 522.4 KB

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df = df.sort_values(['scheme_name', 'date'])
df.head()
# Out:
#             date      nav    scheme_name  scheme_code
# 13409 2012-12-31  23.9920  Axis Bluechip       119092
# 13408 2013-01-01  23.9979  Axis Bluechip       119092
# 13407 2013-01-02  24.0036  Axis Bluechip       119092
# 13406 2013-01-03  24.0092  Axis Bluechip       119092
# 13405 2013-01-04  24.0147  Axis Bluechip       119092

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df['date'], df['nav'])
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df = df.sort_values(['scheme_name', 'date'])

# %%
import os
import pandas as pd

BASE_DIR = r"d:\mutual_fund_analytics"
file_path = os.path.join(BASE_DIR, "data/raw/multi_scheme_nav.csv")

df = pd.read_csv(file_path)
df.head()
# Out:
#          date       nav   scheme_name  scheme_code
# 0  02-06-2026  104.7663  SBI Bluechip       119551
# 1  01-06-2026  104.7025  SBI Bluechip       119551
# 2  29-05-2026  104.6570  SBI Bluechip       119551
# 3  27-05-2026  104.5833  SBI Bluechip       119551
# 4  26-05-2026  104.5269  SBI Bluechip       119551

# %%
import pandas as pd

df = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv")
df.head()
# Out:
#          date       nav   scheme_name  scheme_code
# 0  02-06-2026  104.7663  SBI Bluechip       119551
# 1  01-06-2026  104.7025  SBI Bluechip       119551
# 2  29-05-2026  104.6570  SBI Bluechip       119551
# 3  27-05-2026  104.5833  SBI Bluechip       119551
# 4  26-05-2026  104.5269  SBI Bluechip       119551

# %%
import os

os.path.exists(r"d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv")
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'd:\\mutual_fund_analytics\\notebooks\\eda.ipynb'

# %%
import os
os.getcwd()
# Out:
# 'd:\\mutual_fund_analytics\\notebooks\\eda.ipynb'

# %%
df = pd.read_csv("../data/raw/multi_scheme_nav.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[265], line 1
# ----> 1 df = pd.read_csv("../data/raw/multi_scheme_nav.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv")
df.head()
# Out:
#          date       nav   scheme_name  scheme_code
# 0  02-06-2026  104.7663  SBI Bluechip       119551
# 1  01-06-2026  104.7025  SBI Bluechip       119551
# 2  29-05-2026  104.6570  SBI Bluechip       119551
# 3  27-05-2026  104.5833  SBI Bluechip       119551
# 4  26-05-2026  104.5269  SBI Bluechip       119551

# %%
BASE_DIR = r"d:\mutual_fund_analytics"
df = pd.read_csv(BASE_DIR + r"\data\raw\multi_scheme_nav.csv")

# %%
df = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv")

# %%
df = pd.read_csv("../data/raw/multi_scheme_nav.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 df = pd.read_csv("../data/raw/multi_scheme_nav.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file == "multi_scheme_nav.csv":
            print(os.path.join(root, file))

# %%
import os
os.getcwd()
# Out:
# 'd:\\mutual_fund_analytics\\notebooks\\eda.ipynb'

# %%
df = pd.read_csv("data/raw/multi_scheme_nav.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df = pd.read_csv("data/raw/multi_scheme_nav.csv")
#       2 df.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
returns.head()
# Out:
#         scheme_name  start_nav   end_nav  return_%
# 0     Axis Bluechip  6158.9665   23.9920  Ellipsis
# 1    ICICI Bluechip   103.5959   15.0253  Ellipsis
# 2    Kotak Bluechip   246.8566   30.6076  Ellipsis
# 3  Nippon Large Cap    97.4783   14.6967  Ellipsis
# 4      SBI Bluechip   104.7663  103.0059  Ellipsis

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(returns['scheme_name'], returns['return_%'])
plt.title("Mutual Fund Returns Comparison")
plt.xticks(rotation=45)
plt.ylabel("Return %")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 4
#       1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure(figsize=(10,5))
# ----> 4 plt.bar(returns['scheme_name'], returns['return_%'])
#       5 plt.title("Mutual Fund Returns Comparison")
#       6 plt.xticks(rotation=45)
#       7 plt.ylabel("Return %")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)   2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
# ...

# %%
returns['return_%'] = ((returns['end_nav'] - returns['start_nav']) / returns['start_nav']) * 100
returns
# Out:
#         scheme_name  start_nav   end_nav   return_%
# 0     Axis Bluechip  6158.9665   23.9920 -99.610454
# 1    ICICI Bluechip   103.5959   15.0253 -85.496241
# 2    Kotak Bluechip   246.8566   30.6076 -87.601061
# 3  Nippon Large Cap    97.4783   14.6967 -84.923106
# 4      SBI Bluechip   104.7663  103.0059  -1.680311

# %%
returns['start_nav'] = pd.to_numeric(returns['start_nav'], errors='coerce')
returns['end_nav'] = pd.to_numeric(returns['end_nav'], errors='coerce')

# %%
returns.dtypes
# Out:
# scheme_name        str
# start_nav      float64
# end_nav        float64
# return_%       float64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(returns['scheme_name'], returns['return_%'])
plt.title("Mutual Fund Returns Comparison")
plt.xticks(rotation=45)
plt.ylabel("Return %")
plt.show()

# %%
returns = df.groupby('scheme_name').agg(
    start_nav=('nav', 'first'),
    end_nav=('nav', 'last')
).reset_index()

returns['return_%'] = ((returns['end_nav'] - returns['start_nav']) / returns['start_nav']) * 100

returns
# Out:
#         scheme_name  start_nav   end_nav   return_%
# 0     Axis Bluechip  6158.9665   23.9920 -99.610454
# 1    ICICI Bluechip   103.5959   15.0253 -85.496241
# 2    Kotak Bluechip   246.8566   30.6076 -87.601061
# 3  Nippon Large Cap    97.4783   14.6967 -84.923106
# 4      SBI Bluechip   104.7663  103.0059  -1.680311

# %%
returns['return_%'] = ...

# %%
returns.head()
# Out:
#         scheme_name  start_nav   end_nav  return_%
# 0     Axis Bluechip  6158.9665   23.9920  Ellipsis
# 1    ICICI Bluechip   103.5959   15.0253  Ellipsis
# 2    Kotak Bluechip   246.8566   30.6076  Ellipsis
# 3  Nippon Large Cap    97.4783   14.6967  Ellipsis
# 4      SBI Bluechip   104.7663  103.0059  Ellipsis

# %%
returns.columns
# Out:
# Index(['scheme_name', 'start_nav', 'end_nav', 'return_%'], dtype='str')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(returns['scheme_name'], returns['return_%'])
plt.title("Mutual Fund Returns Comparison")
plt.xticks(rotation=45)
plt.ylabel("Return %")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 4
#       1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure(figsize=(10,5))
# ----> 4 plt.bar(returns['scheme_name'], returns['return_%'])
#       5 plt.title("Mutual Fund Returns Comparison")
#       6 plt.xticks(rotation=45)
#       7 plt.ylabel("Return %")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\pyplot.py:2989, in bar(x, height, width, bottom, align, data, **kwargs)
#    2978 @_copy_docstring_and_deprecators(Axes.bar)
#    2979 def bar(
#    2980     x: float | ArrayLike,
#    (...)   2987     **kwargs,
#    2988 ) -> BarContainer:
# -> 2989     return gca().bar(
#    2990         x,
#    2991         height,
#    2992         width=width,
#    2993         bottom=bottom,
# ...

# %%
returns['return_%'] = ((returns['end_nav'] - returns['start_nav']) / returns['start_nav']) * 100
returns
# Out:
#         scheme_name  start_nav   end_nav   return_%
# 0     Axis Bluechip  6158.9665   23.9920 -99.610454
# 1    ICICI Bluechip   103.5959   15.0253 -85.496241
# 2    Kotak Bluechip   246.8566   30.6076 -87.601061
# 3  Nippon Large Cap    97.4783   14.6967 -84.923106
# 4      SBI Bluechip   104.7663  103.0059  -1.680311

# %%
returns.columns
# Out:
# Index(['scheme_name', 'start_nav', 'end_nav', 'return_%'], dtype='str')

# %%
returns.head()
# Out:
#         scheme_name  start_nav   end_nav   return_%
# 0     Axis Bluechip  6158.9665   23.9920 -99.610454
# 1    ICICI Bluechip   103.5959   15.0253 -85.496241
# 2    Kotak Bluechip   246.8566   30.6076 -87.601061
# 3  Nippon Large Cap    97.4783   14.6967 -84.923106
# 4      SBI Bluechip   104.7663  103.0059  -1.680311

# %%
returns['return_%']
# Out:
# 0   -99.610454
# 1   -85.496241
# 2   -87.601061
# 3   -84.923106
# 4    -1.680311
# Name: return_%, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.bar(returns['scheme_name'], returns['return_%'])
plt.title("Mutual Fund Returns Comparison")
plt.xticks(rotation=45)
plt.ylabel("Return %")
plt.show()

# %%
returns['return_%'] = ((returns['end_nav'] - returns['start_nav']) / returns['start_nav']) * 100

returns.sort_values('return_%', ascending=False)
# Out:
#         scheme_name  start_nav   end_nav   return_%
# 4      SBI Bluechip   104.7663  103.0059  -1.680311
# 3  Nippon Large Cap    97.4783   14.6967 -84.923106
# 1    ICICI Bluechip   103.5959   15.0253 -85.496241
# 2    Kotak Bluechip   246.8566   30.6076 -87.601061
# 0     Axis Bluechip  6158.9665   23.9920 -99.610454

# %%
returns = df.groupby('scheme_name').agg(
    start_nav=('nav', 'first'),
    end_nav=('nav', 'last')
).reset_index()

returns
# Out:
#         scheme_name  start_nav   end_nav
# 0     Axis Bluechip  6158.9665   23.9920
# 1    ICICI Bluechip   103.5959   15.0253
# 2    Kotak Bluechip   246.8566   30.6076
# 3  Nippon Large Cap    97.4783   14.6967
# 4      SBI Bluechip   104.7663  103.0059

# %%
df = df.sort_values(['scheme_name', 'date'])
df.head()
# Out:
#              date        nav    scheme_name  scheme_code
# 13408  01-01-2013    23.9979  Axis Bluechip       119092
# 13104  01-01-2014    26.2235  Axis Bluechip       119092
# 12803  01-01-2015    28.6160  Axis Bluechip       119092
# 12502  01-01-2016  3102.3838  Axis Bluechip       119092
# 12203  01-01-2017  3341.6261  Axis Bluechip       119092

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(data=df, x="date", y="nav", hue="scheme_name")
plt.title("NAV Comparison Across Funds")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df['date'], df['nav'])
plt.title("Mutual Fund NAV Trend")
plt.xlabel("Date")
plt.ylabel("NAV")
plt.show()

# %%
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 16712 entries, 13408 to 98
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         16712 non-null  str
#  1   nav          16712 non-null  float64
#  2   scheme_name  16712 non-null  str
#  3   scheme_code  16712 non-null  int64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 652.8 KB

# %%
import pandas as pd

df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df = df.sort_values('date')
df.head()
# Out:
#             date      nav       scheme_name  scheme_code
# 13409 2012-12-31  23.9920     Axis Bluechip       119092
# 13408 2013-01-01  23.9979     Axis Bluechip       119092
# 13407 2013-01-02  24.0036     Axis Bluechip       119092
# 6544  2013-01-02  15.0253    ICICI Bluechip       120503
# 9843  2013-01-02  14.6967  Nippon Large Cap       118632

# %%
import pandas as pd

df = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv")
df.head()
# Out:
#          date       nav   scheme_name  scheme_code
# 0  02-06-2026  104.7663  SBI Bluechip       119551
# 1  01-06-2026  104.7025  SBI Bluechip       119551
# 2  29-05-2026  104.6570  SBI Bluechip       119551
# 3  27-05-2026  104.5833  SBI Bluechip       119551
# 4  26-05-2026  104.5269  SBI Bluechip       119551

# %%
import os
os.getcwd()
# Out:
# 'd:\\mutual_fund_analytics\\notebooks\\eda.ipynb'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("../data/raw/multi_scheme_nav.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[91], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../data/raw/multi_scheme_nav.csv")
#       4 df.head()
#
# ...
