# %%
import nbconvert
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import nbconvert
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nbconvert\__init__.py:6
#       3 from ._version import __version__, version_info
#       5 try:
# ----> 6     from . import filters, postprocessors, preprocessors, writers
#       7     from .exporters import (
#       8         ASCIIDocExporter,
#       9         Exporter,
#    (...)     27         get_exporter,
#      28     )
#      29 except ModuleNotFoundError:
#      30     # We hit this condition when the package is not yet fully installed.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nbconvert\filters\__init__.py:18
# ...

# %%
# %run 02_eda_analysis.ipynb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_line_magic('run', '02_eda_analysis.ipynb')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nbformat\__init__.py:14
#      10 from pathlib import Path
#      12 from traitlets.log import get_logger
# ---> 14 from . import v1, v2, v3, v4
#      15 from ._version import __version__, version_info
#      16 from .sentinel import Sentinel
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nbformat\v4\__init__.py:24
#       5 from __future__ import annotations
#       7 __all__ = [
#       8     "nbformat",
#       9     "nbformat_minor",
#    (...)     21     "upgrade",
#      22 ]
# ...

# %%
import os
os.listdir()
# Out:
# ['01_data_ingestion.ipynb', '02_eda_analysis.ipynb']

# %%
# %run eda.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'eda.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('run', 'eda.ipynb')
#
# Exception: File `'eda.ipynb'` not found.

# %%
# %run notebooks/eda.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'notebooks/eda.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', 'notebooks/eda.ipynb')
#
# Exception: File `'notebooks/eda.ipynb'` not found.
