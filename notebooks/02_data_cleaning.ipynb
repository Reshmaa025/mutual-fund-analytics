# %%
import os

for root, dirs, files in os.walk("C:\\"):
    for file in files:
        if "nav_history" in file.lower():
            print(os.path.join(root, file))
# Out:
# C:\Users\RESHMA J\Downloads\02_nav_history (1).csv
# C:\Users\RESHMA J\Downloads\02_nav_history.csv

# %%
import pandas as pd

nav = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\nav_history.csv")
nav.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[25], line 3
#       1 import pandas as pd
#       2
# ----> 3 nav = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\nav_history.csv")
#       4 nav.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:575, in pandas._libs.parsers.TextReader.__cinit__()
# --> 575 'Could not get source, probably due dynamically evaluated source code.'
#
# EmptyDataError: No columns to parse from file

# %%
import os

for root, dirs, files in os.walk("d:\\"):
    for file in files:
        if "nav" in file.lower():
            print(os.path.join(root, file))
# Out:
# d:\everyversions\dynamicgraph\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\everyversions\dynamicgraph\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\everyversions\dynamicgraph\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\everyversions\dynamicgraph\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\everyversions\dynamicgraph\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\everyversions\final\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\everyversions\final\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\everyversions\final\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\everyversions\final\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\everyversions\final\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\everyversions\weakness\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\everyversions\weakness\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\everyversions\weakness\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\everyversions\weakness\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\everyversions\weakness\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\mutual_fund_analytics\live_nav_fetch.py
# d:\mutual_fund_analytics\data\raw\02_nav_history.csv
# d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv
# d:\mutual_fund_analytics\notebooks\reports\charts\nav_distribution.png
# d:\mutual_fund_analytics\notebooks\reports\charts\nav_trend.png
# d:\oracle\test\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\oracle\test\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\oracle\test\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\oracle\test\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\oracle\test\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\React Programs\my-react-app\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\reshh\test\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\reshh\test\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\reshh\test\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\reshh\test\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\reshh\test\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\retainX\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\retainX\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\retainX\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\retainX\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\retainX\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\retainX - Copy\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\retainX - Copy\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\retainX - Copy\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\retainX - Copy\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\retainX - Copy\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js
# d:\retention\vite-project\node_modules\antd\es\steps\style\nav.d.ts
# d:\retention\vite-project\node_modules\antd\es\steps\style\nav.js
# d:\retention\vite-project\node_modules\antd\lib\steps\style\nav.d.ts
# d:\retention\vite-project\node_modules\antd\lib\steps\style\nav.js
# d:\retention\vite-project\node_modules\caniuse-lite\data\features\nav-timing.js

# %%
import os

BASE = r"d:\mutual_fund_analytics"

os.makedirs(BASE + r"\data\raw", exist_ok=True)
os.makedirs(BASE + r"\data\processed", exist_ok=True)

print("Folders created")
# Out:
# Folders created

# %%
import os
print(os.listdir(".."))
# Out:
# ['.git', '.gitignore', '.vscode', 'amfi_validation.py', 'analysis.py', 'dashboard', 'data', 'data_ingestion', 'fund_master_explore.py', 'hdfc_top100_live.csv', 'live_nav_fetch.py', 'New folder', 'notebooks', 'performance.py', 'README.md', 'reports', 'requirements.txt', 'sql', 'visualization.py']

# %%
import os

print("CURRENT DIRECTORY:")
print(os.getcwd())

print("\nFILES IN CURRENT FOLDER:")
print(os.listdir("."))
# Out:
# CURRENT DIRECTORY:
# d:\mutual_fund_analytics\notebooks
#
# FILES IN CURRENT FOLDER:
# ['01_data_ingestion.ipynb', '02_data_cleaning.ipynb', '03_sql_database.ipynb', 'eda.ipynb', 'mutual_fund.db', 'reports']

# %%
nav = pd.read_csv("../data/raw/nav_history.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 nav = pd.read_csv("../data/raw/nav_history.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/nav_history.csv'

# %%
import os
print(os.getcwd())
# Out:
# d:\mutual_fund_analytics\notebooks

# %%
import os
print(os.listdir("data/raw"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import os
# ----> 2 print(os.listdir("data/raw"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/raw'

# %%
import os
print(os.getcwd())
# Out:
# d:\mutual_fund_analytics\notebooks

# %%
import pandas as pd

nav = pd.read_csv("data/raw/nav_history.csv")

# 1. Parse date
nav["date"] = pd.to_datetime(nav["date"], errors="coerce")

# 2. Sort
nav = nav.sort_values(["amfi_code", "date"])

# 3. Remove duplicates
nav = nav.drop_duplicates()

# 4. Validate NAV > 0
nav = nav[nav["nav"] > 0]

# 5. Forward fill missing NAV (per fund)
nav["nav"] = nav.groupby("amfi_code")["nav"].ffill()

# Save
nav.to_csv("data/processed/nav_history_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2
# ----> 3 nav = pd.read_csv("data/raw/nav_history.csv")
#       4
#       5 # 1. Parse date
#       6 nav["date"] = pd.to_datetime(nav["date"], errors="coerce")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/nav_history.csv'
