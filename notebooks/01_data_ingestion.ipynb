# %%
df = pd.read_csv("['01_fund_master.csv',
 '02_nav_history.csv',
 '03_aum_by_fund_house.csv',
 '04_monthly_sip_inflows.csv',
 '05_category_inflows.csv',
 '06_industry_folio_count (2).csv',
 '07_scheme_performance.csv',
 '08_investor_transactions.csv',
 '09_portfolio_holdings.csv',
 '10_benchmark_indices.csv',
 'all_mutual_funds.csv',
 'hdfc_top100.csv',
 'hdfc_top100_clean.csv',
 'multi_scheme_nav.csv']")
# Out:
#   Cell In[11], line 1
#     df = pd.read_csv("['01_fund_master.csv',
#                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import os
print(os.getcwd())
# Out:
# d:\mutual_fund_analytics\notebooks

# %%
import os
os.listdir("../data/raw")
# Out:
# ['01_fund_master.csv',
#  '02_nav_history.csv',
#  '03_aum_by_fund_house.csv',
#  '04_monthly_sip_inflows.csv',
#  '05_category_inflows.csv',
#  '06_industry_folio_count (2).csv',
#  '07_scheme_performance.csv',
#  '08_investor_transactions.csv',
#  '09_portfolio_holdings.csv',
#  '10_benchmark_indices.csv',
#  'all_mutual_funds.csv',
#  'hdfc_top100.csv',
#  'hdfc_top100_clean.csv',
#  'multi_scheme_nav.csv']

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

plt.plot(df["month"], df["nav"])
plt.title("NAV Trend")

plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(df["month"], df["nav"])
#       4 plt.title("NAV Trend")
#       5
#       6 plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df["month"], df["nav"])
plt.title("NAV Trend")

plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.plot(df["month"], df["nav"])
#       2 plt.title("NAV Trend")
#       3
#       4 plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
#
# NameError: name 'df' is not defined

# %%
plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
#
# NameError: name 'plt' is not defined

# %%
# %run eda.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'eda.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 get_ipython().run_line_magic('run', 'eda.ipynb')
#
# Exception: File `'eda.ipynb'` not found.

# %%
import os
print(os.getcwd())
# Out:
# d:\mutual_fund_analytics\notebooks

# %%
import pandas as pd

df1 = pd.read_csv("../data/raw/01_fund_master.csv")
df2 = pd.read_csv("../data/raw/02_nav_history.csv")
df3 = pd.read_csv("../data/raw/03_aum_by_fund_house.csv")
df4 = pd.read_csv("../data/raw/04_monthly_sip_inflows.csv")

# %%
import os

base_path = "d:/mutual_fund_analytics/data/raw"

df1 = pd.read_csv(os.path.join(base_path, "01_fund_master.csv"))

# %%
import os
os.listdir("../data/raw")
# Out:
# ['01_fund_master.csv',
#  '02_nav_history.csv',
#  '03_aum_by_fund_house.csv',
#  '04_monthly_sip_inflows.csv',
#  '05_category_inflows.csv',
#  '06_industry_folio_count (2).csv',
#  '07_scheme_performance.csv',
#  '08_investor_transactions.csv',
#  '09_portfolio_holdings.csv',
#  '10_benchmark_indices.csv',
#  'all_mutual_funds.csv',
#  'hdfc_top100.csv',
#  'hdfc_top100_clean.csv',
#  'multi_scheme_nav.csv']

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(df["month"], df["nav"])   # 1. plot data
plt.title("NAV Trend")             # 2. add title

plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")  # 3. save
plt.show()                         # 4. display
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure()
#       4
# ----> 5 plt.plot(df["month"], df["nav"])   # 1. plot data
#       6 plt.title("NAV Trend")             # 2. add title
#       7
#       8 plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")  # 3. save
#
# NameError: name 'df' is not defined

# %%
sample_fund = df["amfi_code"].iloc[0]

df1 = df[df["amfi_code"] == sample_fund]

df1 = df1.sort_values("date")

plt.figure()

plt.plot(df1["date"], df1["nav"])
plt.title(f"NAV Trend - {sample_fund}")

plt.savefig("reports/charts/fund_trend.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure()

plt.hist(df["nav"], bins=20)
plt.title("NAV Distribution")
plt.xlabel("NAV")
plt.ylabel("Frequency")

plt.savefig("reports/charts/nav_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt

top10 = fund_perf.head(10)

plt.figure(figsize=(10,5))

plt.bar(top10["amfi_code"], top10["nav"])
plt.title("Top 10 Funds by Average NAV")
plt.xlabel("Fund Code")
plt.ylabel("Average NAV")

plt.xticks(rotation=45)

plt.savefig("reports/charts/top_funds.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
fund_perf = df.groupby("amfi_code")["nav"].mean().reset_index()
fund_perf = fund_perf.sort_values("nav", ascending=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df["date"] = pd.to_datetime(df["date"])
df = df.sort_values("date")

plt.figure()

plt.plot(df["date"], df["nav"])
plt.title("NAV Trend Over Time")
plt.xlabel("Date")
plt.ylabel("NAV")

plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(df["date"], df["nav"])
plt.title("NAV Trend")

plt.xlabel("Date")
plt.ylabel("NAV")

plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
plt.plot(df["Month"], df["Value"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
plt.plot(df["Date"], df["NAV"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
df.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='str')

# %%
import matplotlib.pyplot as plt

plt.plot(df["month"], df["nav"])
plt.title("NAV Trend")

plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
df = pd.read_csv("../data/raw/02_nav_history.csv")

# %%
import pandas as pd

# %%
plt.savefig("reports/charts/nav_trend.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# %run notebooks/eda.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# OSError: File `'notebooks/eda.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 get_ipython().run_line_magic('run', 'notebooks/eda.ipynb')
#
# Exception: File `'notebooks/eda.ipynb'` not found.

# %%
notebooks/eda.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 notebooks/eda.ipynb
#
# NameError: name 'notebooks' is not defined

# %%
plt.figure()
plt.plot(df['date'], df['nav'])

plt.savefig("reports/charts/nav_trend.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['date'], df['nav'])
plt.title("NAV Trend")

plt.savefig("reports/charts/nav_trend.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['date'], df['nav'])
plt.title("NAV Trend")

plt.savefig("reports/charts/nav_trend.png")
plt.show()

# %%
df = pd.read_csv(r"d:\mutual_fund_analytics\data\raw\multi_scheme_nav.csv")
df.head()
# Out:
#          date       nav   scheme_name  scheme_code
# 0  02-06-2026  104.7663  SBI Bluechip       119551
# 1  01-06-2026  104.7025  SBI Bluechip       119551
# 2  29-05-2026  104.6570  SBI Bluechip       119551
# 3  27-05-2026  104.5833  SBI Bluechip       119551
# 4  26-05-2026  104.5269  SBI Bluechip       119551

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot([1,2,3],[10,20,30])

plt.savefig("reports/charts/test.png")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot([1,2,3],[10,20,30])

plt.savefig("reports/charts/nav_trend.png")
plt.show()

# %%
import os
os.makedirs("reports/charts", exist_ok=True)

# %%
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    
    print("\nINFO:", file)
    df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 for file in files:
#       2     df = pd.read_csv(os.path.join(path, file))
#       3
#       4     print("\nINFO:", file)
#
# NameError: name 'files' is not defined

# %%
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    
    print("\nDATA TYPES:", file)
    print(df.dtypes)
# Out:
# DATA TYPES: 01_fund_master.csv
# amfi_code               int64
# fund_house                str
# scheme_name               str
# category                  str
# sub_category              str
# plan                      str
# launch_date               str
# benchmark                 str
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager              str
# risk_category             str
# sebi_category_code        str
# dtype: object
#
# DATA TYPES: 02_nav_history.csv
# amfi_code      int64
# date             str
# nav          float64
# dtype: object
#
# DATA TYPES: 03_aum_by_fund_house.csv
# date                  str
# fund_house            str
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object
#
# DATA TYPES: 04_monthly_sip_inflows.csv
# month                            str
# sip_inflow_crore               int64
# ...

# %%
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    
    print("\nDUPLICATES in:", file)
    print(df.duplicated().sum())
# Out:
# DUPLICATES in: 01_fund_master.csv
# 0
#
# DUPLICATES in: 02_nav_history.csv
# 0
#
# DUPLICATES in: 03_aum_by_fund_house.csv
# 0
#
# DUPLICATES in: 04_monthly_sip_inflows.csv
# 0
#
# DUPLICATES in: 05_category_inflows.csv
# 0
#
# DUPLICATES in: 06_industry_folio_count (2).csv
# 0
#
# DUPLICATES in: 07_scheme_performance.csv
# 0
#
# DUPLICATES in: 08_investor_transactions.csv
# 0
#
# DUPLICATES in: 09_portfolio_holdings.csv
# 0
#
# DUPLICATES in: 10_benchmark_indices.csv
# 0
#
# DUPLICATES in: all_mutual_funds.csv
# 0
#
# DUPLICATES in: hdfc_top100.csv
# 0
#
# DUPLICATES in: hdfc_top100_clean.csv
# 0

# %%
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    
    print("\nMISSING VALUES:", file)
    print(df.isnull().sum())
# Out:
# MISSING VALUES: 01_fund_master.csv
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64
#
# MISSING VALUES: 02_nav_history.csv
# amfi_code    0
# date         0
# nav          0
# dtype: int64
#
# MISSING VALUES: 03_aum_by_fund_house.csv
# date              0
# fund_house        0
# aum_lakh_crore    0
# aum_crore         0
# num_schemes       0
# dtype: int64
#
# MISSING VALUES: 04_monthly_sip_inflows.csv
# month                         0
# sip_inflow_crore              0
# active_sip_accounts_crore     0
# new_sip_accounts_lakh         0
# sip_aum_lakh_crore            0
# yoy_growth_pct               12
# dtype: int64
#
# ...

# %%
for file in files:
    df = pd.read_csv(os.path.join(path, file))
    
    print("\nFILE:", file)
    print("SHAPE:", df.shape)
    print(df.head())
# Out:
# FILE: 01_fund_master.csv
# SHAPE: (40, 15)
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
# ...

# %%
path = "../data/raw"
files = [f for f in os.listdir(path) if f.endswith(".csv")]
files
# Out:
# ['01_fund_master.csv',
#  '02_nav_history.csv',
#  '03_aum_by_fund_house.csv',
#  '04_monthly_sip_inflows.csv',
#  '05_category_inflows.csv',
#  '06_industry_folio_count (2).csv',
#  '07_scheme_performance.csv',
#  '08_investor_transactions.csv',
#  '09_portfolio_holdings.csv',
#  '10_benchmark_indices.csv',
#  'all_mutual_funds.csv',
#  'hdfc_top100.csv',
#  'hdfc_top100_clean.csv']

# %% [markdown]
# # Data Ingestion Project
# ## Step 1: Load Data

# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %%
import pandas as pd
import numpy as np
import os
